# %% [markdown]
# Data science project
#
# EDA for University Health Survey Dataset
#
# Women and men are in separated .csv files and treated as separate.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

#Download the preprosessed data

womenuhs = pd.read_csv('uhswomen.csv')
menuhs = pd.read_csv('uhsmen.csv')

display(womenuhs.head())
display(menuhs.head())

menuhs.columns
# Out:
#    ylterv  unih  riituni  yöheräily  hermostun  masennus  ahdistus  unettom
# 0       1   7.0        2          1          0         1         1        2  \
# 1       1   9.0        1          0          1         1         0        1
# 2       2   7.0        3          0          0         0         0        2
# 3       1   8.0        1          0          0         0         0        1
# 4       1   9.0        1          2          0         2         2        2
#
#    stressi  liikunta  ...  kasviksia  puuroa  jugurtti  karkki  alkoholia
# 0        3         3  ...          3       1         1       1          4  \
# 1        3         3  ...          3       0         3       2          3
# 2        2         1  ...          4       3         1       3          2
# 3        1         2  ...          3       3         3       1          0
# 4        3         4  ...          2       2         3       1          2
#
#    keskustella  läheisiä  kavereita  ikäryhmä        bmi
# 0            4         4          4         3  18.818924
# 1            2         8          6         3  25.510204
# 2            4         5          7         1  20.202020
# 3            4         1         14         2  21.048048
# 4            4         2          5         2  23.588329
#
# [5 rows x 32 columns]
#    ylterv  unih  riituni  yöheräily  hermostun  masennus  ahdistus  unettom
# 0       2  10.0        1          1          2         0         1        1  \
# 1       1   8.0        3          0          0         0         0        1
# 2       1   7.0        2          0          0         0         0        2
# 3       1   7.0        1          0          0         0         0        1
# 4       1   8.0        2          3          3         3         3        4
#
#    stressi  liikunta  ...  kasviksia  puuroa  jugurtti  karkki  alkoholia
# 0        2         3  ...          2       0         3       1          3  \
# 1        1         1  ...          1       0         1       1          2
# 2        2         3  ...          1       0         0       3          5
# 3        1         4  ...          3       3         3       1          2
# 4        4         3  ...          2       2         2       1          3
#
#    keskustella  läheisiä  kavereita  ikäryhmä        bmi
# 0            4         3          2         2  21.161600
# 1            4         5         12         2  23.163373
# 2            1         2          3         2  20.657540
# 3            4         1          4         3  24.489796
# 4            2         1          3         3  22.839506
#
# [5 rows x 32 columns]
# Index(['ylterv', 'unih', 'riituni', 'yöheräily', 'hermostun', 'masennus',
#        'ahdistus', 'unettom', 'stressi', 'liikunta', 'liiktunteina',
#        'hyötyliiktunteina', 'kevytliik', 'aamupala', 'lounas', 'päivällinen',
#        'miettii_terveel', 'ruisleipää', 'täysjyvää', 'vaaleaaleipää', 'levite',
#        'marj/hedel', 'kasviksia', 'puuroa', 'jugurtti', 'karkki', 'alkoholia',
#        'keskustella', 'läheisiä', 'kavereita', 'ikäryhmä', 'bmi'],
#       dtype='object')

# %% [markdown]
# Histograms for both of the datasets

# %%
womenuhs.hist(figsize=(20,15))
plt.show()

# %%
menuhs.hist(figsize=(20,15))
plt.show()

# %% [markdown]
# Some overall statistics for women.

# %%
womenuhs.describe()
# Out:
#             ylterv         unih      riituni    yöheräily    hermostun
# count  1151.000000  1151.000000  1151.000000  1151.000000  1151.000000  \
# mean      1.591659     7.889661     1.868810     0.880104     0.754996
# std       0.687832     0.894907     0.749023     0.884384     0.793949
# min       1.000000     4.000000     1.000000     0.000000     0.000000
# 25%       1.000000     7.000000     1.000000     0.000000     0.000000
# 50%       1.000000     8.000000     2.000000     1.000000     1.000000
# 75%       2.000000     8.000000     2.000000     1.000000     1.000000
# max       5.000000    12.000000     4.000000     3.000000     3.000000
#
#           masennus     ahdistus      unettom      stressi     liikunta  ...
# count  1151.000000  1151.000000  1151.000000  1151.000000  1151.000000  ...  \
# mean      0.681147     0.470026     1.926151     2.039965     2.919201  ...
# std       0.801076     0.733494     0.775002     0.846559     1.076017  ...
# min       0.000000     0.000000     1.000000     1.000000     0.000000  ...
# 25%       0.000000     0.000000     1.000000     1.000000     2.000000  ...
# 50%       1.000000     0.000000     2.000000     2.000000     3.000000  ...
# 75%       1.000000     1.000000     2.000000     3.000000     4.000000  ...
# max       3.000000     3.000000     4.000000     4.000000     5.000000  ...
#
#          kasviksia       puuroa     jugurtti      karkki    alkoholia
# count  1151.000000  1151.000000  1151.000000  1151.00000  1151.000000  \
# mean      2.414422     1.593397     1.833189     1.42311     1.957428
# std       1.148655     1.216449     1.180999     0.90359     1.083839
# min       0.000000     0.000000     0.000000     0.00000     0.000000
# 25%       2.000000     1.000000     1.000000     1.00000     1.000000
# 50%       2.000000     1.000000     2.000000     1.00000     2.000000
# 75%       3.000000     3.000000     3.000000     2.00000     3.000000
# max       5.000000     5.000000     5.000000     5.00000     5.000000
#
#        keskustella     läheisiä    kavereita     ikäryhmä          bmi
# count  1151.000000  1151.000000  1151.000000  1151.000000  1151.000000
# mean      3.526499     4.906169     5.857515     2.234579    22.286971
# std       0.776246     2.795317     3.644965     0.931882     3.017188
# min       0.000000     0.000000     0.000000     1.000000    16.979592
# 25%       3.000000     3.000000     3.500000     1.000000    20.195335
# 50%       4.000000     4.000000     5.000000     2.000000    21.644121
# 75%       4.000000     6.000000     7.000000     3.000000    23.629240
# max       4.000000    26.000000    27.000000     4.000000    37.552052
#
# [8 rows x 32 columns]

# %% [markdown]
# Some overall statistics for men.

# %%
menuhs.describe()
# Out:
#            ylterv        unih     riituni   yöheräily   hermostun    masennus
# count  613.000000  613.000000  613.000000  613.000000  613.000000  613.000000  \
# mean     1.491028    7.831974    1.903752    0.675367    0.528548    0.427406
# std      0.685042    0.859105    0.731327    0.798690    0.710278    0.654321
# min      1.000000    5.000000    1.000000    0.000000    0.000000    0.000000
# 25%      1.000000    7.000000    1.000000    0.000000    0.000000    0.000000
# 50%      1.000000    8.000000    2.000000    0.000000    0.000000    0.000000
# 75%      2.000000    8.000000    2.000000    1.000000    1.000000    1.000000
# max      4.000000   10.000000    4.000000    3.000000    3.000000    3.000000
#
#          ahdistus     unettom     stressi    liikunta  ...   kasviksia
# count  613.000000  613.000000  613.000000  613.000000  ...  613.000000  \
# mean     0.275693    1.714519    1.771615    2.959217  ...    2.236542
# std      0.575093    0.739900    0.783851    1.147589  ...    1.065426
# min      0.000000    1.000000    1.000000    0.000000  ...    0.000000
# 25%      0.000000    1.000000    1.000000    2.000000  ...    1.000000
# 50%      0.000000    2.000000    2.000000    3.000000  ...    2.000000
# 75%      0.000000    2.000000    2.000000    4.000000  ...    3.000000
# max      3.000000    4.000000    4.000000    5.000000  ...    5.000000
#
#            puuroa    jugurtti      karkki   alkoholia  keskustella
# count  613.000000  613.000000  613.000000  613.000000   613.000000  \
# mean     1.438825    1.668842    1.239804    2.375204     3.185971
# std      1.233357    1.179741    0.836024    1.225880     0.964059
# min      0.000000    0.000000    0.000000    0.000000     0.000000
# 25%      0.000000    1.000000    1.000000    2.000000     3.000000
# 50%      1.000000    2.000000    1.000000    2.000000     3.000000
# 75%      3.000000    3.000000    2.000000    3.000000     4.000000
# max      5.000000    5.000000    5.000000    5.000000     4.000000
#
#          läheisiä   kavereita    ikäryhmä         bmi
# count  613.000000  613.000000  613.000000  613.000000
# mean     3.916803    5.544861    2.337684   23.961758
# std      2.514909    3.627243    0.879226    2.791153
# min      0.000000    0.000000    1.000000   17.617725
# 25%      2.000000    3.000000    2.000000   22.093170
# 50%      3.000000    5.000000    2.000000   23.566632
# 75%      5.000000    7.000000    3.000000   25.451114
# max     21.000000   24.000000    4.000000   35.834194
#
# [8 rows x 32 columns]

# %% [markdown]
# Let's take a closer look into sleep distributions in both of the sets.
